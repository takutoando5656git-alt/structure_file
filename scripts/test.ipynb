# %%
# !python3 --version
# Out:
# Python 3.11.1

# %%
# # 以下 matglの場合
# !pip install ase==3.23.0
# !pip install matgl==1.1.3
# !pip install matplotlib==3.10.0
# !pip install numpy==1.26.4 --user
# !pip install pymatgen==2024.5.1 --user
# !pip install pytorch-lightning==2.0.9 --user
# !pip install scipy==1.14.1
# !pip install torch==2.2.1 --user
# !pip install dgl==2.2.1

# !pip install scikit-learn
# Out:
# Requirement already satisfied: ase==3.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.23.0)
# Requirement already satisfied: numpy>=1.18.5 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from ase==3.23.0) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ase==3.23.0) (1.14.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ase==3.23.0) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (23.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase==3.23.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase==3.23.0) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matgl==1.1.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.1.3)
# Requirement already satisfied: ase in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matgl==1.1.3) (3.23.0)
# Requirement already satisfied: dgl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matgl==1.1.3) (2.2.0)
# Requirement already satisfied: pymatgen in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from matgl==1.1.3) (2024.5.1)
# Requirement already satisfied: lightning in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matgl==1.1.3) (2.5.1)
# Requirement already satisfied: torch in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from matgl==1.1.3) (2.2.1)
# Requirement already satisfied: pydantic in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matgl==1.1.3) (1.10.21)
# Requirement already satisfied: torchdata<0.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matgl==1.1.3) (0.7.1)
# Requirement already satisfied: numpy>=1.14.0 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from dgl>=2.0.0->matgl==1.1.3) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dgl>=2.0.0->matgl==1.1.3) (1.14.1)
# Requirement already satisfied: networkx>=2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dgl>=2.0.0->matgl==1.1.3) (3.2.1)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dgl>=2.0.0->matgl==1.1.3) (2.32.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dgl>=2.0.0->matgl==1.1.3) (4.66.1)
# Requirement already satisfied: psutil>=5.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dgl>=2.0.0->matgl==1.1.3) (5.9.5)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dgl>=2.0.0->matgl==1.1.3) (2.2.3)
# Requirement already satisfied: urllib3>=1.25 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torchdata<0.8.0->matgl==1.1.3) (1.26.16)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch->matgl==1.1.3) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch->matgl==1.1.3) (4.12.2)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch->matgl==1.1.3) (1.12)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch->matgl==1.1.3) (3.1.2)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch->matgl==1.1.3) (2024.9.0)
# Requirement already satisfied: matplotlib>=3.3.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ase->matgl==1.1.3) (3.10.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightning->matgl==1.1.3) (6.0.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightning->matgl==1.1.3) (0.11.7)
# Requirement already satisfied: packaging<25.0,>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightning->matgl==1.1.3) (23.1)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightning->matgl==1.1.3) (1.4.2)
# Requirement already satisfied: pytorch-lightning in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from lightning->matgl==1.1.3) (2.0.9)
# Requirement already satisfied: monty>=2024.2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (2024.7.30)
# Requirement already satisfied: palettable>=3.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (3.3.3)
# Requirement already satisfied: plotly>=4.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (5.24.1)
# Requirement already satisfied: pybtex in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (0.24.0)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (0.18.6)
# Requirement already satisfied: spglib>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (2.5.0)
# Requirement already satisfied: tabulate in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (0.9.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (3.2.2)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen->matgl==1.1.3) (1.3.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (3.10.9)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->matgl==1.1.3) (65.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase->matgl==1.1.3) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase->matgl==1.1.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase->matgl==1.1.3) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase->matgl==1.1.3) (1.4.4)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase->matgl==1.1.3) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase->matgl==1.1.3) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.3.4->ase->matgl==1.1.3) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from plotly>=4.5.0->pymatgen->matgl==1.1.3) (9.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->dgl>=2.0.0->matgl==1.1.3) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->dgl>=2.0.0->matgl==1.1.3) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->dgl>=2.0.0->matgl==1.1.3) (2023.5.7)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ruamel.yaml>=0.17.0->pymatgen->matgl==1.1.3) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch->matgl==1.1.3) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->dgl>=2.0.0->matgl==1.1.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->dgl>=2.0.0->matgl==1.1.3) (2023.3)
# Requirement already satisfied: latexcodec>=1.0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pybtex->pymatgen->matgl==1.1.3) (3.0.0)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pybtex->pymatgen->matgl==1.1.3) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->torch->matgl==1.1.3) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (1.14.0)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->matgl==1.1.3) (0.2.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib==3.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from matplotlib==3.10.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (23.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib==3.10.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.10.0) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy==1.26.4 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pymatgen==2024.5.1 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (2024.5.1)
# Requirement already satisfied: matplotlib>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (3.10.0)
# Requirement already satisfied: monty>=2024.2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (2024.7.30)
# Requirement already satisfied: networkx>=2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (3.2.1)
# Requirement already satisfied: numpy>=1.25.0 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from pymatgen==2024.5.1) (1.26.4)
# Requirement already satisfied: palettable>=3.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (3.3.3)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (2.2.3)
# Requirement already satisfied: plotly>=4.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (5.24.1)
# Requirement already satisfied: pybtex in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (0.24.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (2.32.3)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (0.18.6)
# Requirement already satisfied: scipy>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (1.14.1)
# Requirement already satisfied: spglib>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (2.5.0)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (1.12)
# Requirement already satisfied: tabulate in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (0.9.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (4.66.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (3.2.2)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymatgen==2024.5.1) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (23.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=1.5->pymatgen==2024.5.1) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from plotly>=4.5.0->pymatgen==2024.5.1) (9.0.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ruamel.yaml>=0.17.0->pymatgen==2024.5.1) (0.2.8)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->pymatgen==2024.5.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->pymatgen==2024.5.1) (2023.3)
# Requirement already satisfied: PyYAML>=3.01 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pybtex->pymatgen==2024.5.1) (6.0.2)
# Requirement already satisfied: latexcodec>=1.0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pybtex->pymatgen==2024.5.1) (3.0.0)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pybtex->pymatgen==2024.5.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->pymatgen==2024.5.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->pymatgen==2024.5.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->pymatgen==2024.5.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->pymatgen==2024.5.1) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->pymatgen==2024.5.1) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pytorch-lightning==2.0.9 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (2.0.9)
# Requirement already satisfied: numpy>=1.17.2 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from pytorch-lightning==2.0.9) (1.26.4)
# Requirement already satisfied: torch>=1.11.0 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from pytorch-lightning==2.0.9) (2.2.1)
# Requirement already satisfied: tqdm>=4.57.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning==2.0.9) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning==2.0.9) (6.0.2)
# Requirement already satisfied: fsspec>2021.06.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (2024.9.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning==2.0.9) (1.4.2)
# Requirement already satisfied: packaging>=17.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning==2.0.9) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning==2.0.9) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytorch-lightning==2.0.9) (0.11.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (3.10.9)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lightning-utilities>=0.7.0->pytorch-lightning==2.0.9) (65.5.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (3.16.1)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.11.0->pytorch-lightning==2.0.9) (3.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->pytorch-lightning==2.0.9) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->torch>=1.11.0->pytorch-lightning==2.0.9) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (3.4)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.9) (0.2.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scipy==1.14.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from scipy==1.14.1) (1.26.4)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torch==2.2.1 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (2.2.1)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch==2.2.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch==2.2.1) (4.12.2)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch==2.2.1) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch==2.2.1) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch==2.2.1) (3.1.2)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch==2.2.1) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch==2.2.1) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->torch==2.2.1) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement dgl==2.2.1 (from versions: 1.1.0, 1.1.1, 1.1.2, 1.1.2.post1, 1.1.3, 2.0.0, 2.1.0, 2.2.0)
# ERROR: No matching distribution found for dgl==2.2.1
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/andotakuto/Library/Python/3.11/lib/python/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import ase 
from ase.constraints import FixAtoms, FixedPlane, FixBondLength, UnitCellFilter
from ase.optimize import LBFGS
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution, Stationary
from ase.md.verlet import VelocityVerlet
from ase.md.langevin import Langevin
from ase.md import MDLogger
from ase import Atoms
from ase.io import read, write
from ase.io import Trajectory
from ase import units
from ase.build import bulk, make_supercell
from ase.visualize import view

import matgl
from matgl.ext.ase import M3GNetCalculator
potential = matgl.load_model("M3GNet-MP-2021.2.8-PES")
calculator = matgl.ext.ase.M3GNetCalculator(potential=potential, stress_weight=0.01)

import numpy as np
import math, random

import os,sys,csv,glob,shutil,re,time
from joblib import Parallel, delayed
args = sys.argv

# sklearn
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matgl/apps/pes.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.element_refs = AtomRef(property_offset=torch.tensor(element_refs, dtype=matgl.float_th))
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matgl/apps/pes.py:75: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("data_mean", torch.tensor(data_mean, dtype=matgl.float_th))
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matgl/apps/pes.py:76: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("data_std", torch.tensor(data_std, dtype=matgl.float_th))
